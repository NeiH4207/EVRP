# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(11)
#!/usr/bin/python
f = open('Data/file_3.txt', 'r')
string = f.read()
str = string.split()
num_of_node = int(str[0])

string2 = f_location.read()
f_location = open('Data/location.txt', 'r')
str2 = string2.split()

X1 = []
X2 = []

for a in str2:
    X2.append(float(a))
loc = []
M = len(X2)
for i in range(M):
    if(i % 3 == 0):
        a = []
        a.append(int(X2[i]))
        a.append(X2[i + 1])
        a.append(X2[i + 2])
        loc.append(a)
        
for i in range(1, num_of_node * 2, 2):
    X1.append([int(str[i]), int(str[i + 1])])


def Location(X):
    for i in range(int(M / 3)):
        k = X[i][0]
        x1 = X[i][1]
        y1 = X[i][2]
        if k == 1:
            plt.plot(x1, y1, 'g^', markersize = 3, alpha = .8)
        if k == 2:
            plt.plot(x1, y1, 'bs', markersize = 6, alpha = .8)
    #plt.xlabel('EVRP', color = 'purple')
    #plt.axis('equal')
    #plt.plot(X[:, 0], X[:, 1])
    #plt.show()

def display(X2):
    for i in range(num_of_node - 1):
        x1, y1, x2, y2 = X2[i][0], X2[i][1], X2[i + 1][0], X2[i + 1][1]
        plt.plot([x1, x2], [y1, y2], color = 'tomato', linewidth = 1)
        #print(x1, y1, x2, y2)
    #plt.xlabel('EVRP', color = 'purple')
   #plt.xlabel('Generation', color = 'black')
    #plt.ylabel('Tour length', color = 'black')
    #plt.show()
    plt.plot(loc[0][1], loc[0][2], 'ro', markersize = 7, alpha = .8)
    plt.savefig('Data/n459k26_graph.pdf',bbox_inches='tight')
    #plt.axis('equal')
    #plt.plot(X[:, 0], X[:, 1])
    #plt.show()

Location(loc)
display(X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e4b90266424> in <module>
#       9 num_of_node = int(str[0])
#      10
# ---> 11 string2 = f_location.read()
#      12 f_location = open('Data/location.txt', 'r')
#      13 str2 = string2.split()
#
# NameError: name 'f_location' is not defined

# %%
import matplotlib.pyplot as plt
def plot(values, export = True, cl = 'red'):
    ax = plt.subplot(111)
    ax.set_xlabel('Generation')
    ax.set_ylabel('Tour-length')
    ax.plot(values, color = cl)
    if export:
        plt.savefig("conv.pdf",bbox_inches='tight')  
        plt.show()  

f_1 = open('Data/conv_file_3.txt', 'r')
f_2 = open('Data/conv_file_4.txt', 'r')
string = f_1.read()
X_1 = list(map(float, string.split()))
string = f_2.read()
X_2 = list(map(float, string.split()))
while(len(X_2) > len(X_1)):
    X_2.pop()
plot(X_1, False, 'blue')
plot(X_2)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f6b646e1c0e3> in <module>
#       2 string = f.read()
#       3 X = list(string.split())
# ----> 4 plot(X, True)
#
# <ipython-input-20-4ccce3ead74d> in plot(values, export, cl)
#       1 def plot(values, export = True, cl = 'red'):
# ----> 2     ax = plt.subplot(200)
#       3     ax.set_title('Training')
#       4     ax.set_xlabel('Episode')
#       5     ax.set_ylabel('Run Time')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     674                 cbook.warn_deprecated("3.3", message=message)
#     675                 rows, cols = map(int, [rows, cols])
# --> 676             gs = GridSpec(rows, cols, figure=figure)
#     677             if isinstance(num, tuple) and len(num) == 2:
#     678                 if not all(isinstance(n, Integral) for n in num):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/gridspec.py in __init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     418         self.figure = figure
#     419
# --> 420         GridSpecBase.__init__(self, nrows, ncols,
#     421                               width_ratios=width_ratios,
#     422                               height_ratios=height_ratios)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/gridspec.py in __init__(self, nrows, ncols, height_ratios, width_ratios)
#      49                 f"Number of rows must be a positive integer, not {nrows}")
#      50         if not isinstance(ncols, Integral) or ncols <= 0:
# ---> 51             raise ValueError(
#      52                 f"Number of columns must be a positive integer, not {ncols}")
#      53         self._nrows, self._ncols = nrows, ncols
#
# ValueError: Number of columns must be a positive integer, not 0
